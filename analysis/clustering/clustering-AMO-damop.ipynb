# %% [markdown]
# ### In this notebook, we'll compare the clustering of atom-ph articles (clustering-atom-ph.ipynb) with DAMOP2016 sessions

# %%
from collections import Counter
import json
from sklearn.externals import joblib

# %%
# First, load cluster predictor for atom-ph articles
# clf = joblib.load('cluster-AMO-winner.pkl') 
# clf = joblib.load('cluster-AMO-optics.pkl')
clf = joblib.load('cluster-AMO.pkl')

# %%
# Second, load articles from DAMOP
with open('../../damop data/damop2016.json') as f:
    damop = json.load(f)

# %%
exclude_list = ['Graduate Student Symposium',
                'DAMOP Prize Session',
                'DAMOP Thesis Prize Session',
               ]

# %%
sessions_all = 0
sessions_one_majority = 0
sessions_two_majority = 0

n_clusters = clf.get_params()['clf__n_clusters']
cluster_to_session = dict((x, []) for x in range(n_clusters))
sessions_unclassified = []

for session in damop:
    abstracts = map(lambda x: x['abstract'], session['abstracts'])
    if (len(abstracts) > 4) and (len(abstracts) < 40):
        y = clf.predict(abstracts)
        count = Counter(y)
        session_number_name = "{}: {}".format(session['number'], session['name'])
        print session_number_name
        sessions_all += 1

        if 1.*count.most_common(1)[0][1] >= 0.5*len(abstracts):
            print 'Majority cluster: {}'.format(count.most_common(1)[0][0])
            sessions_one_majority += 1
            
            cluster_to_session[count.most_common(1)[0][0]].append(session_number_name + ' (*)')
            
        elif 1.*(count.most_common(2)[0][1] + count.most_common(2)[1][1]) >= 0.5*len(abstracts):
            print 'Majority clusters: {}, {}'.format(count.most_common(2)[0][0], count.most_common(2)[1][0])
            sessions_two_majority += 1
            
            cluster_to_session[count.most_common(2)[0][0]].append(session_number_name)
            cluster_to_session[count.most_common(2)[1][0]].append(session_number_name)
            
        else:
            print y
            sessions_unclassified.append(session_number_name)
        print ''
        
        if session['number'] == 'A1':
            break
# Out:
# 1A: Graduate Student Symposium
# Majority cluster: 9
#
# B3: Quantum Gases with Dipolar Interactions
# [ 2  5  5  9 11 14 10]
#
# B4: Quantum Optics I
# Majority cluster: 9
#
# B5: Many-Body Localization and Disorder
# Majority cluster: 14
#
# B6: Progress in Spin-Orbit Coupling
# Majority cluster: 12
#
# B7: Nonlinear Optics and Lasers
# Majority cluster: 9
#
# B9: Photoionization, Photodetachment and Photodissociation
# Majority cluster: 18
#
# C4: Hybrid Quantum Systems
# Majority clusters: 3, 9
#
# C5: BEC with Strong Interactions
# Majority clusters: 5, 8
#
# C6: Quantum Gas Microscope
# Majority clusters: 11, 10
#
# C7: Atomic Clocks
# Majority cluster: 0
#
# C9: Strong-Field Physics in Atoms, Molecules, and Clusters
# Majority cluster: 18
#
# G4: Quantum Measurement
# Majority clusters: 9, 3
#
# G5: Atomic Magnetometers I
# Majority cluster: 3
#
# G6: One-Dimensional Gases and Nanofibers
# Majority clusters: 2, 9
#
# G7: Interaction Effects in Spin-Orbit Coupled Gases
# Majority clusters: 12, 1
#
# G8: Time-Resolved Electron Dynamics and Attosecond Spectroscopy
# Majority cluster: 18
#
# G9: Optical Lattices and Quantum Magnetism
# Majority cluster: 11
#
# H4: Quantum Networks and Protocols
# Majority cluster: 9
#
# H5: Electric-Dipole Searches and Tests of Fundamental Symmetries
# Majority cluster: 6
#
# H6: Two-Dimensional Gases
# Majority clusters: 19, 3
#
# H7: Few-body Systems
# Majority clusters: 5, 1
#
# H8: Molecular Control and Imaging
# Majority cluster: 18
#
# H9: Rydberg Polaritons and Rydberg EIT
# Majority cluster: 16
#
# J3: Ultrafast X-ray Processes
# Majority cluster: 18
#
# J4: Quantum Information Theory
# Majority cluster: 14
#
# J5: Precision Measurements
# Majority clusters: 13, 7
#
# J6: Spinor Gases
# Majority clusters: 3, 4
#
# J7: Effects of Collisions
# Majority clusters: 17, 10
#
# J8: Impurities in Quantum Gases
# [14 15  9  9 19 16  3  9  2  8]
#
# J9: Rydberg Atoms and Ultracold Plasmas
# Majority clusters: 16, 6
#
# M2: Many-Body Physics in Quantum Simulation
# Majority cluster: 14
#
# M3: Focus: Cold and Ultracold Molecules
# Majority cluster: 10
#
# M4: Quantum Optics II
# Majority cluster: 9
#
# M5: Quantum Control I
# Majority clusters: 9, 3
#
# M6: Excitations in Bose-Einstein Condensates
# Majority clusters: 8, 9
#
# M7: Time-resolved Molecular Dynamics and Femtochemistry
# Majority cluster: 18
#
# M9: Novel Phases and Ordering in Fermi Gases
# Majority clusters: 12, 11
#
# N4: Quantum Simulation
# Majority cluster: 14
#
# N5: Atom Interferometers
# Majority cluster: 9
#
# N6: Strongly Interacting Fermions
# Majority cluster: 19
#
# N7: Long-range or Anisotropic Interactions in Cold Gases
# [14 16  3  1 15  8  8 11 12  4]
#
# N8: Electronic, Atomic, and Molecular Collisions
# Majority clusters: 17, 7
#
# N9: Cold and Ultracold Molecules II
# Majority clusters: 10, 9
#
# P3: Interfacing Nanophotonics with Cold Atoms
# Majority cluster: 9
#
# P4: Quantum Gates and Computation
# Majority clusters: 9, 10
#
# P5: Transport and Spatial Dynamics
# Majority clusters: 14, 8
#
# P6: Cooling Methods and Interacting BEC's
# Majority cluster: 10
#
# P7: Novel Light Sources and Imaging Techniques
# Majority cluster: 18
#
# P8: Ultracold Bi-Alkalis
# Majority clusters: 6, 9
#
# P9: Quantum Control II
# Majority clusters: 14, 0
#
# T5: New Techniques for Laser Cooling and Trapping
# Majority cluster: 10
#
# T6: Atomic Magnetometers II
# Majority cluster: 3
#
# T7: Spectroscopy, Lifetimes, Oscillator Strengths
# Majority clusters: 0, 7
#
# T8: Quench Dynamics in Degenerate Gases
# Majority clusters: 14, 8
#
# T9: Rydberg Molecules and Dressing
# Majority cluster: 16
#
# U3: Long Range Interactions
# Majority clusters: 11, 16
#
# U5: Precision Experiments
# Majority cluster: 9
#
# U6: Photoassociation and Collisons, Optical Feshbach Resonances
# Majority cluster: 5

# %% [markdown]
# #### Print DAMOP sessions that fall into each cluster.

# %%
order_centroids = clf.named_steps['clf'].cluster_centers_.argsort()[:, ::-1]

terms =  clf.named_steps['vect'].get_feature_names()

for cluster, val in cluster_to_session.iteritems():
    print "Cluster {}: {}".format(cluster, ', '.join([terms[x] for x in order_centroids[cluster, :10]]))
    for session in val:
        print '    {}'.format(session)
    print ''
# Out:
# Cluster 0: frequency, laser, clock, optical, nm, transition, spectroscopy, clocks, 10, comb
#     C7: Atomic Clocks (*)
#     P9: Quantum Control II
#     T7: Spectroscopy, Lifetimes, Oscillator Strengths
#
# Cluster 1: spin, spin orbit, orbit, orbit coupling, spin orbit coupling, coupling, rashba, soc, phase, orbit coupled
#     G7: Interaction Effects in Spin-Orbit Coupled Gases
#     H7: Few-body Systems
#
# Cluster 2: fermi, gas, density, fermi gas, temperature, bose, interacting, interaction, bose gas, dimensional
#     G6: One-Dimensional Gases and Nanofibers
#
# Cluster 3: spin, magnetic, magnetic field, field, fields, atoms, magnetic fields, quantum, state, states
#     C4: Hybrid Quantum Systems
#     G4: Quantum Measurement
#     G5: Atomic Magnetometers I (*)
#     H6: Two-Dimensional Gases
#     J6: Spinor Gases
#     M5: Quantum Control I
#     T6: Atomic Magnetometers II (*)
#
# Cluster 4: vortex, vortices, condensate, bose einstein, einstein, bose, condensates, turbulence, rotating, dynamics
#     J6: Spinor Gases
#
# Cluster 5: body, scattering, bound, scattering length, length, efimov, range, states, universal, resonances
#     C5: BEC with Strong Interactions
#     H7: Few-body Systems
#     U6: Photoassociation and Collisons, Optical Feshbach Resonances (*)
#
# Cluster 6: electric, dipole, electric dipole, moment, edm, dipole moment, molecules, electric dipole moment, electric field, field
#     H5: Electric-Dipole Searches and Tests of Fundamental Symmetries (*)
#     J9: Rydberg Atoms and Ultracold Plasmas
#     P8: Ultracold Bi-Alkalis
#
# Cluster 7: calculations, relativistic, electron, ions, nuclear, levels, states, results, transitions, energy
#     J5: Precision Measurements
#     N8: Electronic, Atomic, and Molecular Collisions
#     T7: Spectroscopy, Lifetimes, Oscillator Strengths
#
# Cluster 8: condensate, bose, bose einstein, einstein, bose einstein condensate, einstein condensate, condensates, bec, einstein condensates, bose einstein condensates
#     C5: BEC with Strong Interactions
#     M6: Excitations in Bose-Einstein Condensates
#     P5: Transport and Spatial Dynamics
#     T8: Quench Dynamics in Degenerate Gases
#
# Cluster 9: atom, light, atomic, atoms, optical, cavity, quantum, photon, state, laser
#     1A: Graduate Student Symposium (*)
#     B4: Quantum Optics I (*)
#     B7: Nonlinear Optics and Lasers (*)
#     C4: Hybrid Quantum Systems
#     G4: Quantum Measurement
#     G6: One-Dimensional Gases and Nanofibers
#     H4: Quantum Networks and Protocols (*)
#     M4: Quantum Optics II (*)
#     M5: Quantum Control I
#     M6: Excitations in Bose-Einstein Condensates
#     N5: Atom Interferometers (*)
#     N9: Cold and Ultracold Molecules II
#     P3: Interfacing Nanophotonics with Cold Atoms (*)
#     P4: Quantum Gates and Computation
#     P8: Ultracold Bi-Alkalis
#     U5: Precision Experiments (*)
#
# Cluster 10: trap, cooling, ion, atoms, optical, ions, laser, trapping, mot, beam
#     C6: Quantum Gas Microscope
#     J7: Effects of Collisions
#     M3: Focus: Cold and Ultracold Molecules (*)
#     N9: Cold and Ultracold Molecules II
#     P4: Quantum Gates and Computation
#     P6: Cooling Methods and Interacting BEC's (*)
#     T5: New Techniques for Laser Cooling and Trapping (*)
#
# Cluster 11: phase, lattice, superfluid, mott, hubbard, model, phases, hubbard model, insulator, transition
#     C6: Quantum Gas Microscope
#     G9: Optical Lattices and Quantum Magnetism (*)
#     M9: Novel Phases and Ordering in Fermi Gases
#     U3: Long Range Interactions
#
# Cluster 12: topological, lattice, states, hall, band, edge, gauge, quantum, quantum hall, chern
#     B6: Progress in Spin-Orbit Coupling (*)
#     G7: Interaction Effects in Spin-Orbit Coupled Gases
#     M9: Novel Phases and Ordering in Fermi Gases
#
# Cluster 13: alpha, proton, mu, hydrogen, structure, hyperfine, fine, muonic, fine structure, variation
#     J5: Precision Measurements
#
# Cluster 14: quantum, systems, time, dynamics, state, non, particle, states, body, equilibrium
#     B5: Many-Body Localization and Disorder (*)
#     J4: Quantum Information Theory (*)
#     M2: Many-Body Physics in Quantum Simulation (*)
#     N4: Quantum Simulation (*)
#     P5: Transport and Spatial Dynamics
#     P9: Quantum Control II
#     T8: Quench Dynamics in Degenerate Gases
#
# Cluster 15: solitons, soliton, dark, bright, dark solitons, dark soliton, nonlinear, einstein, bose einstein, bright solitons
#
# Cluster 16: rydberg, atoms, rydberg atoms, states, rydberg states, excitation, dipole, state, blockade, atom
#     H9: Rydberg Polaritons and Rydberg EIT (*)
#     J9: Rydberg Atoms and Ultracold Plasmas
#     T9: Rydberg Molecules and Dressing (*)
#     U3: Long Range Interactions
#
# Cluster 17: cross, cross sections, sections, cross section, section, electron, ionization, energy, scattering, differential
#     J7: Effects of Collisions
#     N8: Electronic, Atomic, and Molecular Collisions
#
# Cluster 18: electron, ionization, laser, field, pulse, time, pulses, harmonic, attosecond, electrons
#     B9: Photoionization, Photodetachment and Photodissociation (*)
#     C9: Strong-Field Physics in Atoms, Molecules, and Clusters (*)
#     G8: Time-Resolved Electron Dynamics and Attosecond Spectroscopy (*)
#     H8: Molecular Control and Imaging (*)
#     J3: Ultrafast X-ray Processes (*)
#     M7: Time-resolved Molecular Dynamics and Femtochemistry (*)
#     P7: Novel Light Sources and Imaging Techniques (*)
#
# Cluster 19: bcs, superfluid, bec, fermi, pairing, crossover, phase, temperature, bcs bec, bec crossover
#     H6: Two-Dimensional Gases
#     N6: Strongly Interacting Fermions (*)

# %%
print 'Sessions without clusters'
for session in sessions_unclassified:
    print session
    print ''
print ''
print 'Clusters without sessions'
for cluster, session in cluster_to_session.iteritems():
    if len(session) == 0:
        print "Cluster {}: {}".format(cluster, ', '.join([terms[x] for x in order_centroids[cluster, :10]]))
# Out:
# Sessions without clusters
# B3: Quantum Gases with Dipolar Interactions
#
# J8: Impurities in Quantum Gases
#
# N7: Long-range or Anisotropic Interactions in Cold Gases
#
#
# Clusters without sessions
# Cluster 15: solitons, soliton, dark, bright, dark solitons, dark soliton, nonlinear, einstein, bose einstein, bright solitons

# %% [markdown]
# #### What fraction of the DAMOP sessions are covered by one or two clusters?

# %%
print (sessions_one_majority)*1./sessions_all
print (sessions_one_majority + sessions_two_majority)*1./sessions_all
print sessions_all
# Out:
# 0.542372881356
# 0.949152542373
# 59
